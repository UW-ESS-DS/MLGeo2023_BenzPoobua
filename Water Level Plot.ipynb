# %% [markdown]
# ## Water Level Plot

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import requests
import io
import time
from datetime import datetime, timedelta
from decimal import Decimal

# %%
#well 10N/16E-21D01
t1 = [1955, 1970, 1970, 1971, 1971, 1971, 1971, 1971, 1972, 1972, 1972, 1972, 1972, 1973, 1973, 1983, 1984, 1985, 1992, 1993, 1994, 1994, 1995, 1995, 1995, 1995, 1995, 1995, 1996, 2000, 2001, 2001, 2001, 2001, 2001]
wl1 = [42, 38.7, 31.4, 29.9, 31.4, 41.2, 37.4, 37.4, 28.7, 30.1, 34.6, 35.04, 33.27, 28.93, 28.8, 32.1, 30.53, 32.19, 56.63, 41.67, 39.63, 43.89, 39.27, 37.01, 36.15, 60.99, 45.47, 38.97, 44.29, 37.83, 36.55, 36.29, 46, 36.3, 37]

#well 11N/19E-10A02
t2 = [1969, 1970, 1971, 1971, 1971, 1972, 1972, 1974, 2000, 2001, 2002]
wl2 = [57, 15.07, 17.2, 25.9, 19.38, 13.7, 31.87, 6.22, 30.63, 15.1, 24.18]

#well 11N/21E-17N01
t3 = [1977, 1981, 1981, 1982, 1982, 1983, 1983, 1983, 1984, 1985, 1985, 1986, 1986, 1988, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1996, 1997, 1998, 1999, 2000, 2000, 2001, 2001, 2002]
wl3 = [247, 249, 247, 245, 246, 243, 244, 242, 244, 241, 243, 237, 299.8, 249, 243, 252, 249, 251, 249, 263.9, 270, 258, 245, 233, 228, 226, 223, 235, 247, 212, 364, 268]

#well 10N/22E-31F01
t4 = [1978, 1983, 1984, 1985, 1986, 1987, 1987, 1988, 1988, 1989, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1998, 1999, 2000, 2000, 2001, 2001, 2002]
wl4 = [45, 58, 57, 64.5, 59.1, 56.4, 70.35, 60.45, 69.74, 60.9, 72.79, 55.53, 58.34, 63.04, 60.16, 56.65, 63, 55.6, 58.83, 87.89, 52.8, 67.78, 60.04, 87.01, 54.42]

#well 08N/24E-05R01
t5 = [1979, 1987, 1988, 1988, 1989, 1989]
wl5 = [35, 42.95, 51.23, 47.35, 51.74, 42.41]

#well 10N/19E-12M01
t6 = [1967, 1967, 1971, 1971, 1971, 1971, 1972]
wl6 = [13, 19, 14.5, 13.96, 12.37, 7.48, 14.5]

#well 11N/17E-30K01
t7 = [1965, 1965, 1970, 1970, 1971, 1971, 1971, 1971, 1971, 1971, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1973, 1993, 1994, 1994, 1994, 1995, 1995, 1996, 1996, 2000, 2001]
wl7 = [128, 130, 169.7, 167.7, 164, 169, 269, 267, 256, 176, 244, 276, 171, 286, 286, 251, 179, 177, 174, 209.52, 219.33, 227.15, 220.39, 222.54, 220.39, 221.09, 220.57, 230.97, 229.98]

plt.figure().set_figwidth(12)
plt.figure().set_figheight(5)

plt.plot(t1, wl1, 'k*', label = '10N/16E-21D01')
plt.plot(t2, wl2, 'b*', label = '11N/19E-10A02')
plt.plot(t3, wl3, 'r*', label = '11N/21E-17N01')
plt.plot(t4, wl4, 'g*', label = '10N/22E-31F01')
plt.plot(t5, wl5, 'c*', label = '08N/24E-05R01')
plt.plot(t6, wl6, 'y*', label = '10N/19E-12M01')
plt.plot(t7, wl7, 'm*', label = '11N/17E-30K01')


plt.xticks(np.arange(min(t1), max(t1)+1, 5.0))
plt.xlabel('Time [years]')
plt.ylabel('Water Level [ft]')
plt.title('Water Level Variation in Yakima Valley')
plt.xlim(1950,2003)
plt.legend(loc = 2)
plt.grid()
plt.show()
plt.savefig('WT_YV.png')
